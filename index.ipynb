# %%
import pandas as pd

# Baca data dari CSV file
dataset = pd.read_csv('KRB_Grid_SB250.csv', usecols=range(0, 13), header=1)
dataset.head()
# Out:
#    NOGRID  BNJRTING  BNJRSED  BBNDGTING  BBNDGSED  TSUNTING  TSUNSED  LIKTING  \
# 0       1     11.94    73.05       6.75     28.89     98.74      0.0    73.93
# 1       2     22.64    16.02       0.00      0.00     57.64      0.0    57.09
# 2       3     41.63    58.07       0.00     15.27     96.41      0.0    38.99
# 3       4      3.97    59.13      16.02      3.97     16.22      0.0     0.00
# 4       5      0.00     0.00      69.82      0.00     26.62      0.0     0.00
#
#    LIKSED  GEMTING  GEMSED  LONGTING  LONGSED
# 0   23.91      0.0   99.07       0.0      0.0
# 1    0.00      0.0   57.09       0.0      0.0
# 2   61.01      0.0  100.00       0.0      0.0
# 3   66.79      0.0   66.79       0.0      0.0
# 4   69.82      0.0   69.82       0.0      0.0
